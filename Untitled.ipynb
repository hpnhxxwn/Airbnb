# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('preprocessed/train_users.csv')

# %%
train=train_data.sample(frac=0.001,random_state=200)

# %%
train
# Out:
#                 id  10_count  11_count  12_count  15_count  about_us_count  \
# 152444  a13homxvt8       NaN       NaN       NaN       NaN             NaN
# 39822   dfvd45veq3       NaN       NaN       NaN       NaN             NaN
# 148690  1i7kwony6m       NaN       NaN       NaN       NaN             NaN
# 81105   tfom04m4an       NaN       NaN       NaN       NaN             NaN
# 40979   kew8lp0k1i       NaN       NaN       NaN       NaN             NaN
# 86683   ubdkn2clw2       NaN       NaN       NaN       NaN             NaN
# 65816   ur62is0bnf       NaN       NaN       NaN       NaN             NaN
# 145832  grhs229u3p       NaN       NaN       NaN       NaN             NaN
# 5398    sblnsf0fwl       NaN       NaN       NaN       NaN             NaN
# 41310   b5pxpjdxij       NaN       NaN       NaN       NaN             NaN
# 130017  n16a6obkwl       NaN       NaN       NaN       NaN             NaN
# ...

# %%
train.to_csv('sampled_training_data.csv')
